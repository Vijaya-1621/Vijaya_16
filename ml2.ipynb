# %% [markdown]
# <a href="https://colab.research.google.com/github/Vijaya-1621/Vijaya_16/blob/main/ml2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

# %%
import pandas as pd

# %%
data=pd.read_csv("/content/heart.csv")

# %%
data
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
le=LabelEncoder()

# %%
oe=OrdinalEncoder()
y=data.iloc[:,-1]
x=data.iloc[:,:-1]

# %%
x
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal
# 0         2   2     3
# 1         0   0     3
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1020    1
# 1021    0
# 1022    0
# 1023    1
# 1024    0
# Name: target, Length: 1025, dtype: int64

# %%
x=oe.fit_transform(x)
y=le.fit_transform(y)

# %%
from sklearn.preprocessing import MinMaxScaler
mms=MinMaxScaler()

# %%
x=mms.fit_transform(x)
y=mms.fit_transform(y)
y=pd.DataFrame(x)

# %%
x
# Out:
# array([[0.45      , 1.        , 0.        , ..., 1.        , 0.5       ,
#         1.        ],
#        [0.475     , 1.        , 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        [0.9       , 1.        , 0.        , ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [0.325     , 1.        , 0.        , ..., 0.5       , 0.25      ,
#         0.66666667],
#        [0.4       , 0.        , 0.        , ..., 1.        , 0.        ,
#         0.66666667],
#        [0.5       , 1.        , 0.        , ..., 0.5       , 0.25      ,
#         1.        ]])

# %%
y
# Out:
#          0    1         2         3         4    5    6         7    8   \
# 0     0.450  1.0  0.000000  0.375000  0.284768  0.0  0.5  0.744444  0.0
# 1     0.475  1.0  0.000000  0.583333  0.225166  1.0  0.0  0.600000  1.0
# 2     0.900  1.0  0.000000  0.645833  0.079470  0.0  0.5  0.277778  1.0
# 3     0.675  1.0  0.000000  0.687500  0.225166  0.0  0.5  0.666667  0.0
# 4     0.700  0.0  0.000000  0.562500  0.768212  1.0  0.5  0.100000  0.0
# ...     ...  ...       ...       ...       ...  ...  ...       ...  ...
# 1020  0.625  1.0  0.333333  0.583333  0.344371  0.0  0.5  0.700000  1.0
# 1021  0.650  1.0  0.000000  0.375000  0.576159  0.0  0.0  0.444444  1.0
# 1022  0.325  1.0  0.000000  0.166667  0.682119  0.0  0.0  0.211111  1.0
# 1023  0.400  0.0  0.000000  0.166667  0.549669  0.0  0.0  0.644444  0.0
# 1024  0.500  1.0  0.000000  0.291667  0.158940  0.0  0.5  0.155556  0.0
#
#             9    10    11        12
# 0     0.256410  1.0  0.50  1.000000
# ...

# %%
y=pd.DataFrame(x)

# %%
from sklearn.model_selection import train_test_split


x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.8,random_state=16)

# %%
from sklearn.svm import SVC
svm=SVC(kernel='linear')

svm.fit(x_train,y_train)
pred=svm.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-f6b124716f72> in <cell line: 3>()
#       1 from sklearn.svm import SVC
#       2 svm=SVC(kernel='linear')
# ----> 3 svm.fit(x_train,y_train)
#       4 pred=svm.predict(x_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     190             check_consistent_length(X, y)
#     191         else:
# --> 192             X, y = self._validate_data(
#     193                 X,
#     194                 y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# ...

# %%
x_train=pd.DataFrame(x_train)
y_train=pd.DataFrame(y_train)

# %%
svm.fit(x_train,y_train)
pred=svm.predict(x_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-b4141ce06fc3> in <cell line: 1>()
# ----> 1 svm.fit(x_train,y_train)
#       2 pred=svm.predict(x_test)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/svm/_base.py in fit(self, X, y, sample_weight)
#     190             check_consistent_length(X, y)
#     191         else:
# --> 192             X, y = self._validate_data(
#     193                 X,
#     194                 y,
#
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py in _validate_data(self, X, y, reset, validate_separately, **check_params)
#     582                 y = check_array(y, input_name="y", **check_y_params)
#     583             else:
# --> 584                 X, y = check_X_y(X, y, **check_params)
#     585             out = X, y
#     586
#
# ...

# %%
from sklearn.metrices import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-43-8a2856f2db56> in <cell line: 1>()
# ----> 1 from sklearn.metrices import accuracy_score
#
# ModuleNotFoundError: No module named 'sklearn.metrices'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
accuracy_score(y_test,pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-46-19cc511cba74> in <cell line: 1>()
# ----> 1 accuracy_score(y_test,pred)
#
# NameError: name 'accuracy_score' is not defined
